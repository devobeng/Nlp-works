# %% [markdown]
# <a href="https://colab.research.google.com/github/devobeng/Nlp-works/blob/main/zeroshot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers

# %%
import pandas as pd
from transformers import pipeline, logging
logging.set_verbosity_error()
pd.set_option("display.max_colwidth", None)

# %%
df=pd.read_excel('./Popchip_Reviews.xlsx')

# %%
df.head()
# Out:
#       Id          UserId  Rating Priority  \
# 0  23689  A21SYVGVNG8RAS       5      Low
# 1  23690   AQJYXC0MPRQJL       5      Low
# 2  23691  A30NYUHEDLWI0Y       5      Low
# 3  23692  A2NU55U9LKTB5J       3     High
# 4  23693  A225F7QFP5LIW2       5      Low
#
#                                         Title  \
# 0                               Yummy snacks!
# 1  Great chip that is different from the rest
# 2          Great  Alternative to Potato Chips
# 3                  Not somthing I would crave
# 4                       healthy and delicious
#
# ...

# %%
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
df['Category']=df['Text'].apply(lambda x:classifier(sequences=x, candidate_labels=['order', 'taste & texture', 'good', 'flavor', 'health'])['labels'][0] )
